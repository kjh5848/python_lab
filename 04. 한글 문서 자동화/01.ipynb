# %%
import win32com.client.gencache as win32
import pandas as pd
excel = pd.read_excel(r'N:\개인\개발폴더\엑셀과 한컴오피스\파이썬 + 한글_자동화\example.xlsx')
print(excel)
# Out:
#         사업장 현황 Unnamed: 1
# 0        사업장 명        ㈜주잇
# 1         대표자명        김주혁
# 2          소재지         부산
# 3           업종        개발업
# 4        피보험자수        10명
# 5          NaN        NaN
# 6       담당자 정보        NaN
# 7         담당부서        NaN
# 8         담당자명        NaN
# 9   전화번호(팩스번호)        NaN
# 10         이메일        NaN

# %%
hwp = win32.gencache.EnsureDispatch("hwpframe.hwpobject")
hwp.RegisterModule("FilePathCheckDLL", "FilePathCheckerModuleExample");
hwp.XHwpWindows.Item(0).Visible = True  # 한글 창을 보이게 설정

# %%
excel = pd.read_excel(
r'N:\개인\개발폴더\엑셀과 한컴오피스\파이썬 + 한글_자동화\샘플\example.xlsx'
)
print(excel)
# Out:
#    일련번호
# 0     1
# 1     2
# 2     3
# 3     4

# %%
hwp.Open(r'N:\개인\개발폴더\엑셀과 한컴오피스\파이썬 + 한글_자동화\[서식34] 인턴형 일경험 실시보고_김상헌멘토.hwp')
# Out:
# True

# %%
try:
    field_list = hwp.GetFieldList()
    print("필드 목록:", field_list)
except Exception as e:
    print("필드 목록을 가져오는 중 오류 발생:", e)
# Out:
# 필드 목록: 사업장명
