# %%
#%%
from utill import excel_utill, hwp_utill
import pandas as pd


# 파일 경로 및 시트 설정
EXCEL_FILE_PATH = r"C:\Users\사용자\Desktop\미래내일일경험\python_lab\07. 한글 문서\[쇼우테크] SNS콘텐츠 마케팅 인턴십.xlsx"
HWP_FILE_NAME = "[서식34] 인턴형 일경험 실시보고"
HWP_FILE_PATH = r'C:\Users\사용자\Desktop\미래내일일경험\python_lab\07. 한글 문서\★누름틀_문서\4. 일경험 시작'
SAVE_FILE_PATH = r"C:\Users\사용자\Desktop\미래내일일경험\사전직무"

# 객체 생성
EObject = excel_utill.ExcelUtill()
HObject = hwp_utill.HwpUtill()

# 여러 시트 데이터 불러오기
sheet_names = [
    "참여자명단",
    "사전직무,운영기관,일경험 정보",
    "참여기업 멘토",
    "참여기업"
    ]

excel_data = EObject.여러시트열기(EXCEL_FILE_PATH, sheet_names, header=0)

# 각 시트 데이터 가져오기
참여자명단 = excel_data["참여자명단"]
사전직무정보 = excel_data["사전직무,운영기관,일경험 정보"]
참여기업 = excel_data["참여기업"]
참여기업멘토 = excel_data["참여기업 멘토"]

# 한글 파일 열기 및 필드 가져오기
grouped = 참여자명단.groupby("담당멘토")

# 참여기업멘토 시트에서 멘토 이름 가져오기
멘토_리스트 = 참여기업멘토['성명'].tolist()

# 그룹의 담당멘토와 참여기업멘토 시트의 이름 매칭
def 한글문서생성():
    field_names = HObject.필드가져오기(HWP_FILE_NAME, HWP_FILE_PATH)
    for 담당멘토, group in grouped:
        
        HObject.파일열기(
            HWP_FILE_NAME,
            HWP_FILE_PATH
        )
        count = len(group)  # 그룹별 참여자 수 계산

        if 담당멘토 in 멘토_리스트:
            HObject.홀짝필드채우기(
            excel_sheet=참여기업,
            field_names=field_names,
            )
            HObject.홀짝필드채우기(
            excel_sheet=사전직무정보,
            field_names=field_names,
            )
            멘토정보 = 참여기업멘토[참여기업멘토['성명'] == 담당멘토].iloc[0]
            
        # 누름틀 채우기
        for field_name in field_names:
            # print(field_name)
            HObject.채우기("참여인원", HObject._포맷팅(count))
            if field_name in 멘토정보.index:  # 멘토정보에 필드가 존재하는 경우
                value = 멘토정보[field_name]  # 필드 값 추출
                HObject.채우기(field_name, value)  # 누름틀에 값 채우기
        
        # field_mapping 생성: 멘토별 누름틀 필드 추출
        field_mapping_group = {
            "성명": [f for f in field_names if f.startswith("성명_")],
            "생년월일": [f for f in field_names if f.startswith("생년월일_")],
            "연락처": [f for f in field_names if f.startswith("연락처_")],
            "성별": [f for f in field_names if f.startswith("성별_")],
            "참여일(4주)": [f for f in field_names if f.startswith("참여일_")],
        }

        # HObject를 사용하여 멘토별로 데이터를 채움
        HObject.fill_fields(
            data=group,  # 멘토별 참여자 명단 데이터
            field_mapping=field_mapping_group
        )

        # 결과 저장 및 닫기
        HObject.저장(f"{HWP_FILE_NAME}_{담당멘토}멘토.hwp", SAVE_FILE_PATH)
        HObject.닫기()

    HObject.저장파일열기(SAVE_FILE_PATH)
    HObject.종료()

한글문서생성()
# Out:
# c:\Users\사용자\Desktop\미래내일일경험\python_lab\04. 한글 문서 자동화\utill\hwp_utill.py:90: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   field_name = row_data[col_index]  # 현재 열 (필드명)
# c:\Users\사용자\Desktop\미래내일일경험\python_lab\04. 한글 문서 자동화\utill\hwp_utill.py:92: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   field_value = row_data[col_index + 1]
# 파일 저장 완료: [서식34] 인턴형 일경험 실시보고_이정구멘토.hwp
# 파일 저장 완료: [서식34] 인턴형 일경험 실시보고_황강연멘토.hwp
