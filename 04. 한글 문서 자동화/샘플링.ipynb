# %%
#%%
from utill import excel_utill, hwp_utill
import pandas as pd


# 파일 경로 및 시트 설정
EXCEL_FILE_PATH = r"C:\Users\Administrator\Desktop\미래내일일경험 공유\python_lab\07. 한글 문서\[쇼우테크] SNS콘텐츠 마케팅 인턴십.xlsx"
HWP_FILE_NAME = "[서식34] 인턴형 일경험 실시보고"
HWP_FILE_PATH = r'C:\Users\Administrator\Desktop\미래내일일경험 공유\python_lab\07. 한글 문서\★누름틀_문서\4. 일경험 시작'
SAVE_FILE_PATH = r"C:\Users\Administrator\Desktop\미래내일일경험 공유\사전직무"

# 객체 생성
EObject = excel_utill.ExcelUtill()
HObject = hwp_utill.HwpUtill()

# 여러 시트 데이터 불러오기
sheet_names = ["참여자명단", "사전직무,운영기관,일경험 정보","참여기업 멘토","참여기업"]
excel_data = EObject.여러시트열기(EXCEL_FILE_PATH, sheet_names, header=0)

# 각 시트 데이터 가져오기
참여자명단 = excel_data["참여자명단"]
사전직무정보 = excel_data["사전직무,운영기관,일경험 정보"]
참여기업멘토 = excel_data["참여기업 멘토"]

참여기업 = excel_data["참여기업"]
# 한글 파일 열기 및 필드 가져오기
field_names = HObject.필드가져오기(HWP_FILE_NAME, HWP_FILE_PATH)

grouped = 참여자명단.groupby("담당멘토")

# 황강연 그룹 가져오기
if "황강연" in grouped.groups.keys():
    hwang_group = grouped.get_group("황강연")
    print("황강연 그룹:")
    print(hwang_group)
else:
    print("황강연 그룹이 없습니다.")

# 이정구 그룹 가져오기
if "이정구" in grouped.groups.keys():
    lee_group = grouped.get_group("이정구")
    print("이정구 그룹:")
    print(lee_group)
else:
    print("이정구 그룹이 없습니다.")


# 결과 저장 및 닫기
HObject.저장(f"{HWP_FILE_NAME}_결과.hwp", SAVE_FILE_PATH)
HObject.닫기()
HObject.종료()
HObject.저장파일열기(SAVE_FILE_PATH)
# Out:
# 황강연 그룹:
#   순번 특이사항 기재           운영기관명           작성날짜      직무 참여시간 일경험 현황 담당멘토  \
# 0  1          (사)한국기술사업화진흥협회  2024년 12월 03일  광고 마케팅    0     실시  황강연
# 1  2          (사)한국기술사업화진흥협회  2024년 12월 03일  광고 마케팅    0     실시  황강연
# 2  3          (사)한국기술사업화진흥협회  2024년 12월 03일  광고 마케팅    0     실시  황강연
# 3  4          (사)한국기술사업화진흥협회  2024년 12월 03일  광고 마케팅    0     실시  황강연
# 4  5          (사)한국기술사업화진흥협회  2024년 12월 03일  광고 마케팅    0     실시  황강연
#
#                    프로그램명   성명  ...     최종학과  \
# 0  [쇼우테크] SNS콘텐츠 마케팅 인턴십  김성재  ...
# 1  [쇼우테크] SNS콘텐츠 마케팅 인턴십  박동기  ...    국어국문과
# 7   [쇼우테크] SNS콘텐츠 마케팅 인턴십  박소희  ...  미디어콘텐츠학과
# 8   [쇼우테크] SNS콘텐츠 마케팅 인턴십  신현수  ...  미디어콘텐츠학과
# 9   [쇼우테크] SNS콘텐츠 마케팅 인턴십  이형덕  ...  미디어콘텐츠학과
# 10  [쇼우테크] SNS콘텐츠 마케팅 인턴십  장효석  ...  미디어콘텐츠학과
# 11  [쇼우테크] SNS콘텐츠 마케팅 인턴십  이다은  ...  미디어콘텐츠학과
# 12  [쇼우테크] SNS콘텐츠 마케팅 인턴십  박수정  ...  미디어콘텐츠학과
# 13  [쇼우테크] SNS콘텐츠 마케팅 인턴십  김진우  ...
# 14  [쇼우테크] SNS콘텐츠 마케팅 인턴십  서민영  ...
#
#                                               주소       은행  \
# 5   경북 포항시 남구 새천년대로 306, 포항효자웰빙타운에스케이뷰 109동 601호    카카오뱅크
# 6                   부산광역시 남구 수영로 276-2 센트럴뷰 802호     토스뱅크
# 7                    부산 남구 유엔로215번길 38 그랑피아 306호     NH농협
# 8                              부산 동구 자성로 116번길 2     케이뱅크
# 9                부산광역시 남구 대연동 43-65 아뜨리에 원룸 101호  IBK기업은행
# 10    경상북도 구미시 고아읍 들성로 11길 46-7(청솔타운 101동 1809호)     NH농협
# 11                  부산 해운대구 세실로 174 , 111동 2201호     NH농협
# 12         부산 부산진구 백양관문로 7 개금동 개금주공아파트 204동 504호     부산은행
# 13                    부산 금정구 부산대학로 10, 112동 902호     국민은행
# 14              부산시 동래구 금강로 151번길 46, 109동 1201호     신한은행
#
#    계좌번호\n(실제 인턴비 받을 계좌, 번복 불가)                 은행명 / 계좌번호 성별    생년월일  출생연도  \
# 5              3333-28-1012968      카카오뱅크/3333-28-1012968  여  050330  2005
# 6               1000-6732-6365        토스뱅크/1000-6732-6365  여  030113  2003
# 7             302-1901-2348-31      NH농협/302-1901-2348-31  여  030617  2003
# 8               100-114-310196        케이뱅크/100-114-310196  남  021012  2002
# 9            256-125982-01-011  IBK기업은행/256-125982-01-011  남  990327  1999
# 10            352-1943-8746-53      NH농협/352-1943-8746-53  남  031018  2003
# 11             302-1336-779511       NH농협/302-1336-779511  여  030316  2003
# 12            112-2259-0331-02      부산은행/112-2259-0331-02  여  030922  2003
# 13                202042580022          국민은행/202042580022  남  061231  2006
# 14                110512847475          신한은행/110512847475  여  030218  2003
#
#    만나이   지역
# 5   19  경상권
# 6   21  경상권
# 7   21  경상권
# 8   22  경상권
# 9   25  경상권
# 10  21  경상권
# 11  21  경상권
# 12  21  경상권
# 13  18  경상권
# 14  21  경상권
#
# [10 rows x 27 columns]
# 파일 저장 완료: [서식34] 인턴형 일경험 실시보고_결과.hwp
