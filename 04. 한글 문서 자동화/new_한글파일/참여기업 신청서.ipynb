# %%
from utill import excel_utill, hwp_utill

# 파일 경로 및 시트 설정
EXCEL_FILE_PATH = r"C:\Users\Administrator\Desktop\미래내일일경험 공유\python_lab\07. 한글 문서\[광고마케팅] 241223 KTCA_30명.xlsx"
EXCEL_SHEET_NAME = "참여자명단"
HWP_FILE_NAME = "참여청년 신청서 모음"
HWP_FILE_PATH = r"C:\Users\Administrator\Desktop\미래내일일경험 공유\python_lab\07. 한글 문서\★누름틀_문서\1. 참여기업 서류"
SAVE_FILE_PATH = r"C:\Users\Administrator\Desktop\미래내일일경험 공유\신청서 모음2"

# 객체 생성
EObject = excel_utill.ExcelUtill()
HObject = hwp_utill.HwpUtill()

# 엑셀 데이터 불러오기
excel_data = EObject.엑셀열기(EXCEL_FILE_PATH, EXCEL_SHEET_NAME, header=0)

def 한글문서생성(HObject, excel_data, hwp_file_name, hwp_file_path, save_file_path):
    """엑셀 데이터를 기반으로 한글 문서를 생성"""
    # 한글 파일에서 필드 이름 가져오기
    field_names = HObject.필드가져오기(hwp_file_name, hwp_file_path)

    for _, row in excel_data.iterrows():
        try:
            # 한글 파일 열기
            HObject.파일열기(hwp_file_name, hwp_file_path)

            # 추가 정보 입력
            HObject.희망직무(row)
            HObject.학력정보입력(row)
        
                # 필드 채우기
            HObject.필드채우기(field_names, row)

            # 저장 경로 확인 및 저장
            HObject.저장폴더(save_file_path)
            new_file_name = f"{hwp_file_name}_{row['성명']}_{row['생년월일']}.hwp"
            HObject.저장(new_file_name, save_file_path)

            print(f"파일 생성 완료: {new_file_name}")
        except Exception as e:
            print(f"오류 발생 (성명: {row['성명']}): {e}")
        finally:
            # 한글 파일 닫기
            HObject.닫기()

    # 저장된 파일 폴더 열기
    HObject.저장파일열기(save_file_path)

    # 한글 종료
    HObject.종료()

        
한글문서생성(
    HObject=HObject,
    excel_data=excel_data,
    hwp_file_name=HWP_FILE_NAME
    ,hwp_file_path=HWP_FILE_PATH,
    save_file_path=SAVE_FILE_PATH
)
# Out:
# 파일 저장 완료: 참여청년 신청서 모음_이민수_900699.hwp
# 파일 생성 완료: 참여청년 신청서 모음_이민수_900699.hwp
# 파일 저장 완료: 참여청년 신청서 모음_정지우_950499.hwp
# 파일 생성 완료: 참여청년 신청서 모음_정지우_950499.hwp
# 파일 저장 완료: 참여청년 신청서 모음_박지우_960399.hwp
# 파일 생성 완료: 참여청년 신청서 모음_박지우_960399.hwp
# 파일 저장 완료: 참여청년 신청서 모음_김예은_930699.hwp
# 파일 생성 완료: 참여청년 신청서 모음_김예은_930699.hwp
# 파일 저장 완료: 참여청년 신청서 모음_이민수_020699.hwp
# 파일 생성 완료: 참여청년 신청서 모음_이민수_020699.hwp
# 파일 저장 완료: 참여청년 신청서 모음_박현우_930899.hwp
# 파일 생성 완료: 참여청년 신청서 모음_박현우_930899.hwp
# 파일 저장 완료: 참여청년 신청서 모음_이현우_001199.hwp
# 파일 생성 완료: 참여청년 신청서 모음_이현우_001199.hwp
# 파일 저장 완료: 참여청년 신청서 모음_김지우_920699.hwp
# 파일 생성 완료: 참여청년 신청서 모음_김지우_920699.hwp
# 파일 저장 완료: 참여청년 신청서 모음_박현우_900699.hwp
# 파일 생성 완료: 참여청년 신청서 모음_박현우_900699.hwp
# 파일 저장 완료: 참여청년 신청서 모음_김현우_900799.hwp
# 파일 생성 완료: 참여청년 신청서 모음_김현우_900799.hwp
# 파일 저장 완료: 참여청년 신청서 모음_정지우_910699.hwp
# 파일 생성 완료: 참여청년 신청서 모음_정지우_910699.hwp
# 파일 저장 완료: 참여청년 신청서 모음_박예은_000899.hwp
# 파일 생성 완료: 참여청년 신청서 모음_박예은_000899.hwp
# 파일 저장 완료: 참여청년 신청서 모음_최현우_921299.hwp
# 파일 생성 완료: 참여청년 신청서 모음_최현우_921299.hwp
# 파일 저장 완료: 참여청년 신청서 모음_이현우_901199.hwp
# 파일 생성 완료: 참여청년 신청서 모음_이현우_901199.hwp
# 파일 저장 완료: 참여청년 신청서 모음_최예은_941099.hwp
# 파일 생성 완료: 참여청년 신청서 모음_최예은_941099.hwp
